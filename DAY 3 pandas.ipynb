# %%
#impoting pandas
import pandas as pd

# %%
A=['jwalitha ','ramya','shannu','siri','malli']
r=pd.Series(A,index=[34,56,78,12,35])
print(r)
# Out:
# 34    jwalitha
# 56        ramya
# 78       shannu
# 12         siri
# 35        malli
# dtype: object

# %%
#cse_D
import pandas as pd

# %%
#series
#pd.series(col,ind)
col = ["joe",'suchi']
ind = [23,45]

# %% [markdown]
# # New Section

# %%
#loading csv
dia=pd.read_csv("/content/csv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grade = pd.read_csv("/content/grades_withnulls.txt",sep=",")
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
diaxl=pd.read_excel("/content/diabetes.xlsx")
diaxl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
demotxt=pd.read_csv("/content/demodt.txt")
demotxt
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxls=pd.read_excel("/content/diabetes.xlsx",sheet_name ="dora")
diaxls
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
#describe
diaxl.describe() #describing a data frame
# Out:
#        Dead Alive
# count     5     5
# unique    1     1
# top     yes    no
# freq      5     5

# %%
demotxt.describe() #describing a data frame
# Out:
#         Literacy  Cleanliness  Crime_Rate       Good
# count  26.000000    26.000000   26.000000  26.000000
# mean   75.269231    77.038462   52.307692   0.423077
# std    12.078270     8.879103    6.208183   0.503831
# min    55.000000    63.000000   41.000000   0.000000
# 25%    67.250000    69.250000   47.250000   0.000000
# 50%    75.500000    77.500000   52.000000   0.000000
# 75%    84.750000    83.750000   57.000000   1.000000
# max    94.000000    92.000000   63.000000   1.000000

# %%
grade.describe() #describing a data frame
# Out:
#        Names Initials SEM1 SEM2 SEM3 Grade Placed
# count                                          17
# unique                                         17
# top                         Joe K 9.8 10 9.9 A+ 1
# freq                                            1

# %%
dia.describe() #describing a data frame
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
#shapes
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (17, 7)
# 17
# 7

# %%
#nan==>true
#syntax:
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna(inplace=True)

# %%
df.dropna(inplace=True)
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
df.dropna()
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna().sum()
# Out:
# Names       JoeRajeshKissanJeenRajHassanMariMayaJolinRajes...
# Initials                                        KMVKMVNNKMMVN
# SEM1                                                    118.2
# SEM2                                                    117.5
# SEM3                                                    117.2
# Grade                                        A+AAA+AABBA+AAAB
# Placed                                                      9
# dtype: object

# %%
df.dropna(inplace=True)#we are using inplace=True to change the place
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace=True)

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mdf=df2.dropna()
mdf
#to save the changes ,create new dataframe or give inplace=True
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555)
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555)

df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True) #changes are saved!
df2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df['SEM1'].mean()
print(mv)
# Out:
# 9.092307692307694

# %%
print(mydf[mydf.index==7])
print("Accessing specific row and col")
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# Accessing specific row and col
# 7    B
# Name: Grade, dtype: object

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df['SEM1'].mean()
print(mv)
df2.fillna(mv,inplace=True)
df2
# Out:
# 9.092307692307694
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   9.092308     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  9.092308   9.1   9.900000    A+       1
# 9   Rajini        M  9.092308   9.1   9.300000     A       0
# 10   Kiran        V  9.092308   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
mydf=pd.read_csv("/content/grades_withnulls.csv")
mydf.dropna()
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#acces the data
#iloc=integer locaton,index
#loc=field nmaes,index
#dfname.loc[index]----->rows
#dfname.loc[st:stop]---->range of rows
#dfname.loc[r_ind,col_name]----->rows&col
mydf.loc[0]#first record
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
mydf.loc[0:5]#first five records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
mydf.loc[8:14]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1

# %%
mydf.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
mydf.iloc[10:2,0:2] #both rows&col---->index
# Out:
# Empty DataFrame
# Columns: [Names, Initials]
# Index: []

# %%
mydf[mydf.SEM2==9.1]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#print records to score 9.3 in sem 3
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
print(mydf[mydf.index==7])
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# 7    B
# Name: Grade, dtype: object

# %%
#range of values
mydf.loc[mydf['SEM1']>9.8,"Names"] #loc[index,colums]
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
#acces the grades of students who scored more than 9 in sem3
mydf.loc[mydf['SEM3']>9,"Grade"]
# Out:
# 0     A+
# 1      A
# 2      A
# 4     A+
# 5      A
# 6      A
# 8     A+
# 9      A
# 10     A
# 12    A+
# 13     A
# 14     A
# 15     A
# Name: Grade, dtype: object

# %%
mydf.loc[mydf['SEM3']>9.7,"Grade"]
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
mydf.drop_duplicates()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.drop_duplicates(inplace=True)
print(mydf)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.drop_duplicates(inplace=False)
print(mydf)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
mydf.tail()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
mydf.tail(7)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#printing one row
print(mydf[mydf.index==1])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#accessing using index function
mydf[mydf.index==7]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1

# %%
#columns!
colnames = mydf.columns #view and save nAMES
print(colnames)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#columns
collist=list(mydf.columns)#view and save names
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#rename a column
mydf.rename(columns={'Grades':"GPA"},inplace=True)
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed',
#        'conduct', 'Average'],
#       dtype='object')

# %%
#rename a column
mydf.rename(columns={'Grades':"GPA"})
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed',
#        'conduct', 'Average'],
#       dtype='object')

# %%
#creating a new column!
#dfname['new col']=values
mydf["conduct"]="Good"
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good
# 3     Mary        N   7.7   8.0   NaN     B       0    Good
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good
# 5      Raj        M   8.9   9.1   9.3     A       1    Good
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good
# 7     Mari        N   7.7   8.0   7.1     B       1    Good
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good
# 11    Maya        N   7.7   8.0   7.1     B       0    Good
# 12   Jolin        K   9.8   9.1   9.9    A+       1    Good
# 14    Riya        M   9.3   9.9  10.0     A       1    Good
# 15    Sana        V   9.9   9.3   9.2     A       0    Good
# ...

# %%
#create a new column with the  average values of sem1 sem2 and sem3
mydf["Average"]=(mydf["SEM1"]+mydf["SEM2"]+mydf["SEM3"])/3

# %%
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...

# %%
#plotting with pandas

mydf['SEM1'].plot.line() #defname['col'].plot.line()
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line() #ploting multiple columns
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line(subplots=True) #all numeric column are ploted!
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
 mydf.plot(kind="scatter",x="Average",y="Names")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
mydf.plot(kind="hist",x="Average",y='SEM1')#yaxis -numeric datatype
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf.plot(kind="hist",x="Names",y='Average')#yaxis -numeric
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...

# %%
mydf.to_csv("mydf.csv")
#syntax
#dfname.to_csv("file name")
